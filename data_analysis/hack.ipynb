# %%
import pandas as pd
import numpy as np

# %%
df_events = pd.read_csv("Мероприятия - ЭНБ Москвы.csv")

# %%
df_catalog = pd.read_csv("Датасеты/Каталог.csv")

# %%
df_catalog.columns
# Out:
# Index(['doc_id', 'p100a', 'p245a', 'p260a', 'p260b', 'p260c', 'p490a', 'p650a',
#        'p084a', 'p521a'],
#       dtype='object')

# %%
df_readers = pd.read_csv("Датасеты/Читатели.csv")

# %%
db = pd.to_datetime(df_readers["Дата рождения"])

# %%
(db.dt.year.value_counts())
# Out:
# 2010.0    19062
# 2009.0    18749
# 2011.0    16586
# 2008.0    16547
# 2007.0    14789
#           ...
# 1912.0        2
# 1911.0        2
# 1899.0        2
# 1919.0        1
# 1918.0        1
# Name: Дата рождения, Length: 107, dtype: int64

# %%
df_events.Статус.unique()

# %%
len(df_events['Наименование учреждения'].unique())

# %%
df_events['Тип учреждения'].unique()

# %%
len(df_events['Подразделение'].unique())

# %%
df_catalog = pd.read_csv("Датасеты/Каталог.csv")

# %%
df_catalog.head()
# Out:
#    Unnamed: 0  doc_id                        p100a          p245a   p260a  \
# 0           0       1  Устинова Татьяна Витальевна  Призрак Канта  Москва
# 1           1       2                          NaN  Наука и жизнь  Москва
# 2           2       3                          NaN  Наука и жизнь     NaN
# 3           3       4                          NaN  Наука и жизнь     NaN
# 4           4       5                          NaN  Наука и жизнь     NaN
#
#                                   p260b  p260c  \
# 0                                 Эксмо   2018
# 1  АНО Редакция журнала «Наука и жизнь»  1938-
# 2                                   NaN   2018
# 3                                   NaN   2018
# 4                                   NaN   2018
#
#                                    p490a  \
# 0  Татьяна Устинова. Первая среди лучших
# 1                                    NaN
# 2                                    NaN
# 3                                    NaN
# ...

# %%
list(df_catalog.p650a.unique())
# Out:
# ['Художественная литература ; Российский детектив',
#  'Наука. Науковедение',
#  'Художественная литература ; Фэнтэзи',
#  'Художественная литература',
#  'Художественная литература ; Фантастика',
#  'Художественная литература ; Художественно-документальная проза. Мемуары',
#  'История в целом. Всемирная история',
#  'Живопись',
#  'Математика',
#  'Краеведение. Страноведение. Путешествия. Путеводители',
#  'Психология труда и профессиональной деятельности',
#  'Психология развития и возрастная психология',
#  'Художественная литература ; Проза',
#  'Право. Юридические науки ; Административное право',
#  'Периодическая печать',
#  'Технологии и средства программирования',
#  'История России',
#  'История науки',
#  'Психология труда и профессиональной деятельности ; Семейное воспитание и образование. Самообразование',
#  'Изобразительное искусство и архитектура',
# ...

# %%
df_give = pd.read_csv("Датасеты/Vydacha_1.csv")
# Out:
# /usr/local/lib/python3.9/site-packages/IPython/core/interactiveshell.py:3146: DtypeWarning: Columns (10) have mixed types.Specify dtype option on import or set low_memory=False.
#   has_raised = await self.run_ast_nodes(code_ast.body, cell_name,

# %%
len(df_give.append(pd.read_csv("Датасеты/Vydacha_2.csv"))['ИД читателя'].unique())
# Out:
# 450572

# %%
df_kdf = pd.read_csv("./КДФ/Classificator_hachaton.csv", sep=';')
df_kdf.head()
# Out:
#    id_классификатора  id_родительского_классификатора  \
# 0            3002985                              NaN
# 1            3002986                        3002985.0
# 2            3002987                        3002985.0
# 3            3002988                        3002985.0
# 4            3002989                              NaN
#
#                  Наименование
# 0                   Автошкола
# 1                    Автоклуб
# 2  Правила дорожного движения
# 3               Юный водитель
# 4                 Архитектура

# %%
len(df_kdf[df_kdf.id_родительского_классификатора.isna()].Наименование.unique())
# Out:
# 36

# %%
df_kdf = pd.read_csv("./КДФ/MegaRelation_hackaton.csv", sep=';')
df_kdf.head()
# Out:
#    id_зачисления  Статус  id_ученика Дата_создания_записи  id_организации  \
# 0        1325954     3.0     25969.0  08.06.2015 14:47:19              30
# 1        2879918     3.0    158129.0  29.10.2015 18:35:21              30
# 2        2901258     3.0    304476.0  02.11.2015 14:05:56              30
# 3        2912724     3.0   1139915.0  03.11.2015 14:29:27              30
# 4        2912819     3.0    298767.0  03.11.2015 14:34:15              30
#
#    id_заявления  id_услуги     дата_зачисления      дата_отчисления  \
# 0      950832.0      39178  08.06.2015 0:00:00  29.02.2016 19:28:12
# 1      989658.0      39178  01.09.2010 0:00:00  29.02.2016 19:23:59
# 2      950764.0      39178  09.06.2014 0:00:00  29.02.2016 19:28:11
# 3      950786.0      39178  09.06.2014 0:00:00  29.02.2016 19:28:11
# 4      950799.0      39178  09.06.2014 0:00:00  29.02.2016 19:28:11
#
#    причина_перевода  предыдущая_запись_зачисления  \
# 0               NaN                           NaN
# ...

# %%
df_kdf = pd.read_csv("./КДФ/org_hackaton.csv", sep=';')
df_kdf.head()
# Out:
#    id_организации                                полное_наименование  \
# 0               1  Государственное бюджетное образовательное учре...
# 1               2  Государственное бюджетное профессиональное обр...
# 2               2  Государственное бюджетное профессиональное обр...
# 3               3  Государственное бюджетное образовательном учре...
# 4               4  Государственное бюджетное образовательное учре...
#
#                                 краткое_наименование                 улица  \
# 0  ГБОУ СПО г.Москвы «Московская средняя специаль...                   NaN
# 1                   ГБПОУ г. Москвы "Академия джаза"  улица Трёхгорный Вал
# 2                   ГБПОУ г. Москвы "Академия джаза"  улица Трёхгорный Вал
# 3  ГБОУ СПО г.Москвы «Московский театральный колл...       улица Чаплыгина
# 4        ГБОУДОД г.Москвы «МГДМШ им. С.С.Прокофьева»     Токмаков переулок
#
#                  Метро
# 0                  NaN
# 1    Краснопресненская
# 2      Улица 1905 года
# ...

# %%
df_kdf = pd.read_csv("./КДФ/Pupil_hackaton.csv", sep=';')
df_kdf.head()
# Out:
#    id_ученика  возраст      пол
# 0           1     12.0  Женский
# 1           2     12.0  Женский
# 2           3     12.0  Женский
# 3           4     11.0  Женский
# 4           5     12.0  Женский

# %%
df_kdf.возраст.value_counts()
# Out:
#  16.0     160898
#  17.0     159392
#  10.0     147233
#  11.0     145795
#  12.0     142317
#            ...
#  109.0         1
# -989.0         1
# -984.0         1
# -974.0         1
# -60.0          1
# Name: возраст, Length: 115, dtype: int64

# %%
df_ex.head()
# Out:
#    Unnamed: 0  Идентификатор экземпляра  ИД Каталожной записи  \
# 0           0                   2830404                399001
# 1           1                   2830403                399001
# 2           2                   2781735                399001
# 3           3                   2781737                399001
# 4           4                   2781738                399001
#
#   Инвентарный номер     Штрих-код Раздел знаний  Идентификатор сиглы
# 0     01:0000019698  181000142300      84(4Шва)                112.0
# 1     01:0000027988  181000441335    84(4Швейц)                113.0
# 2     02:0000583817  280005456044      84(4Шва)                 81.0
# 3     02:0000855574  280011962379    84(4Швейц)                 87.0
# 4     02:0000462824  280008297767      84(4Шва)                 87.0

# %%
import numpy as np
from sklearn.datasets import load_digits
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd
# %matplotlib inline

# %%
import umap

# %%
import pandas as pd

# %%
pd.read_pickle("word-model.pkl").to_pickle("word_model.pickle")
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-3-811d58aaa6fd> in <module>
# ----> 1 pd.read_pickle("word-model.pkl").to_pickle("word_model.pickle")
#
# AttributeError: 'Word2VecKeyedVectors' object has no attribute 'to_pickle'
