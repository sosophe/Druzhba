# %%
import pandas as pd

# %%
ratings = pd.read_csv("../final_data/vydacha_rated.csv")
ratings.rename({"Штрих-код": "itemid", "ИД читателя": "userid"}, inplace=True, axis=1)
# ratings["rating"] = 1.0
ratings.tail()
# Out:
#           Unnamed: 0  ИД выдачи  userid Инвентарный номер_x        itemid  \
# 10877125    10877125   11423335  388940       09:0000722640  980009027645
# 10877126    10877126   11423356   57347       01:0000813506  181009423486
# 10877127    10877127   11423371  452490       09:0000140762  900001407627
# 10877128    10877128   11423381  566212       08:0000469319  880004721237
# 10877129    10877129   11423382  435542       09:0000722644  980009027652
#
#           Идентификатор экземпляра  ИД Каталожной записи   doc_id  \
# 10877125                  15082507                240179   240179
# 10877126                   4106819                370353   370353
# 10877127                  13200176               1216514  1216514
# 10877128                   9889224                336559   336559
# 10877129                  15082547                240179   240179
#
#                                      p100a  \
# 10877125             Курлат Феликс Львович
# 10877126  Мамин-Сибиряк Дмитрий Наркисович
# 10877127                    Функе Корнелия
# 10877128                   Линдгрен Астрид
# 10877129             Курлат Феликс Львович
#
#                                                    p245a  \
# 10877125                     Москва. От центра до окраин
# 10877126                                     Серая шейка
# 10877127                              Бесстрашная Игрэйн
# 10877128  Братья Львиное сердце; Кале Блумквист и Расмус
# 10877129                     Москва. От центра до окраин
#
#                               p650a p521a    rating
# 10877125             История России   NaN  0.043478
# 10877126  Художественная литература   NaN  0.521739
# 10877127  Художественная литература    0+  0.311475
# 10877128  Художественная литература   NaN  1.000000
# 10877129             История России   NaN  0.045082
