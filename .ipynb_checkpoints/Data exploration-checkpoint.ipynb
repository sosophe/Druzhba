# %%
import pandas as pd
import os
import pickle

# %%
# xls = pd.ExcelFile("../Мероприятия/Events.xlsx")
# df_ex_2 = pd.DataFrame()
# for sheet in xls.sheet_names:
#     print(sheet)
#     df = pd.read_excel(xls, sheet)
#     print('parsed')
#     df_ex_2 = df_ex_2.append(df)
#     print('next')
# df_ex_2.to_csv("Мероприятия.csv")
# Out:
# ЭНБ Москвы
# parsed
# next

# %% [markdown]
# # Мероприятия

# %%
# # parallel map

# def parallelize_dataframe(df, func, n_cores=4):
#     df_split = np.array_split(df, n_cores)
#     pool = Pool(n_cores)
#     df = pd.concat(pool.map(func, df_split))
#     pool.close()
#     pool.join()
#     return df

# %%
path = "../final_data/Мероприятия.csv"

# %%
pd.read_csv(path, nrows=4)
# Out:
#    Unnamed: 0    id                               Название мероприятия  \
# 0           0     5  Фестивлаь современных молодежных уличных культ...
# 1           1    12  Танцевальный вечер "Ретро" в честь Дня Победы ...
# 2           2  3179                                           Врасплох
# 3           3   486  Праздник Новогодней елки. Новогодний концерт в...
#
#       Статус                Наименование учреждения Тип учреждения  \
# 0  Завершено     ГБУК г. Москвы «Клуб «Современник»  Дома культуры
# 1  Завершено           ГБУК г.Москвы «ДК «Нагорный»  Дома культуры
# 2  Завершено          ГБУК г. Москвы «ДК «Нагатино»  Дома культуры
# 3  Завершено  ГАУК г. Москвы «Культурный центр ЗИЛ»  Дома культуры
#
#    Подразделение Стоимость (полная)                     Тип мероприятия  \
# 0            NaN         бесплатное                           фестиваль
# 1            NaN         бесплатное             танцевальный вечер, бал
# 2            NaN         бесплатное                            выставка
# 3            NaN         бесплатное  концерт, музыкальное представление
#
#   Направленность мероприятия  ...  \
# 0        культурно-досуговое  ...
# 1             патриотическое  ...
# 2                 антитеррор  ...
# 3        культурно-досуговое  ...
#
#                                     Краткое описание Проводится онлайн  \
# 0  Клуб Современник проведет фестиваль современны...               Нет
# 1      Танцевальный вечер "Ретро" в честь Дня Победы               Нет
# 2  Регулярное (ежеквартальное) мероприятие цикла ...               Нет
# 3  Коллектив Культурного центра ЗИЛ Ансамбль эстр...               Нет
#
#                     Место проведения                         Округ  \
# 0                                NaN                           NaN
# 1      Электролитный пр. 3, корпус 1  Южный административный округ
# 2  Судостроительная ул. 31, корпус 1  Южный административный округ
# 3                     Россия, Москва                           NaN
#
#                Район Доступность мероприятия для лиц с ОВЗ Тип ОВЗ  \
# 0                NaN                            недоступно     NaN
# 1           Нагорный                            недоступно     NaN
# 2  Нагатинский Затон                                   NaN     NaN
# 3                NaN                                   NaN     NaN
#
#   Возрастной ценз участников мероприятия Возрастная категория  \
# 0                                     0+          от 20 до 40
# 1                                    16+          от 40 до 85
# 2                                     6+         от 16 до 100
# 3                                     0+           от 5 до 14
#
#                                    Целевая аудитория
# 0                                                NaN
# 1          работающая молодежь, взрослые, пенсионеры
# 2  школьники, работающая молодежь, студенческая м...
# 3               дети дошкольного возраста, школьники
#
# [4 rows x 26 columns]

# %% [markdown]
# ### Тип мероприятия

# %%
import collections

# %%
event_type = pd.read_csv(path, usecols=["Тип мероприятия"])

# %%
def bar_plot_events(event_type, target, legend=None):
    print("Мы имеем ", len(set(event_type[target].dropna())), " различных представителей")
    count = collections.Counter(event_type.values.ravel())
    ax = (
        pd.DataFrame(sorted(count.items(), key=lambda pair: pair[1], reverse=True))
        .dropna()
        .set_index(0)
        .plot(kind="bar", figsize=(15, 6))
    )
    if legend:
        ax.legend([legend])

# %%
bar_plot_events(event_type, target="Тип мероприятия", legend="Количество типов мероприятия")
# Out:
# Мы имеем  35  различных представителей

# %% [markdown]
# ### Направленность мероприятия

# %%
bar_plot_events(
    pd.read_csv(path, usecols=["Направленность мероприятия"]),
    target="Направленность мероприятия",
    legend="Количество типов направленностей мероприятий",
)
# Out:
# Мы имеем  72  различных представителей

# %% [markdown]
# ### Округ

# %%
bar_plot_events(
    pd.read_csv(path, usecols=["Округ"]),
    target="Округ",
    legend="Количество мероприятий по округам",
)
# Out:
# Мы имеем  12  различных представителей

# %% [markdown]
# ### Район

# %%
bar_plot_events(
    pd.read_csv(path, usecols=["Район"]),
    target="Район",
    legend="Количество мероприятий по районам",
)
# Out:
# Мы имеем  139  различных представителей

# %% [markdown]
# ### Возрастной ценз участников мероприятия

# %%
bar_plot_events(
    pd.read_csv(path, usecols=["Возрастной ценз участников мероприятия"]),
    target="Возрастной ценз участников мероприятия",
    legend="Количество мероприятий по Возрастным цензам",
)
# Out:
# Мы имеем  5  различных представителей

# %%
bar_plot_events(
    pd.read_csv(path, usecols=["Возрастная категория"]),
    target="Возрастная категория",
    legend="Количество мероприятий по Возрастнам категориям",
)
# Out:
# Мы имеем  669  различных представителей

# %%
age = pd.read_csv(path, usecols=["Возрастная категория", "Возрастной ценз участников мероприятия"])
age["low"] = age["Возрастная категория"].apply(lambda x: x.split()[1])
age["high"] = age["Возрастная категория"].apply(lambda x: x.split()[3] if len(x.split()) == 4 else "no_limits")
age[age["high"] == "no_limits"]
# Out:
#       Возрастной ценз участников мероприятия Возрастная категория  low  \
# 68                                        0+               от 680  680
# 165                                       0+                 от 3    3
# 186                                       6+                от 10   10
# 471                                       6+     от 6 до 12 до 16    6
# 473                                      18+                от 18   18
# ...                                      ...                  ...  ...
# 40934                                     0+                 от 4    4
# 40935                                     0+                 от 4    4
# 40938                                     0+                 от 5    5
# 40949                                     0+                 от 5    5
# 40992                                     0+                 от 4    4
#
#             high
# 68     no_limits
# 165    no_limits
# 186    no_limits
# 471    no_limits
# 473    no_limits
# ...          ...
# 40934  no_limits
# 40935  no_limits
# 40938  no_limits
# 40949  no_limits
# 40992  no_limits
#
# [1012 rows x 4 columns]

# %% [markdown]
# Так как Возрастной ценз участников мероприятия сопряжен с Возрастной категорией, то мы исключим Возрастные категории из рассмотрения

# %% [markdown]
# ### Целевая аудитория

# %%
pd.read_csv(path, usecols=["Целевая аудитория"]).dropna().head()
# Out:
#                                    Целевая аудитория
# 1          работающая молодежь, взрослые, пенсионеры
# 2  школьники, работающая молодежь, студенческая м...
# 3               дети дошкольного возраста, школьники
# 4  дети дошкольного возраста, школьники, работающ...
# 5               дети дошкольного возраста, школьники

# %%
people_cat = pd.read_csv(path, usecols=["Целевая аудитория"]).dropna().values.ravel()

# %%
count = collections.Counter([word.strip() for word in ",".join(people_cat).split(",")])
ax = (
        pd.DataFrame(sorted(count.items(), key=lambda pair: pair[1], reverse=True))
        .dropna()
        .set_index(0)
        .plot(kind="bar", figsize=(15, 6))
    )
ax.legend(["Количество мероприятий по Целевой аудитории"])

# %%
def parallelize_dataframe(df, func, n_cores=4):
    df_split = np.array_split(df, n_cores)
    pool = Pool(n_cores)
    df = pd.concat(pool.map(func, df_split))
    pool.close()
    pool.join()
    return df

# %%
# Мы заменяем "других" на все типы
common_target_group = ", ".join(count.keys()).replace(", другое", "")

events.loc[events["Целевая аудитория"] == "другое", "Целевая аудитория"] = common_target_group

# %%
d = {1: 'yes', 0: 'no'}
people_cat2 = pd.read_csv(path, usecols=["Целевая аудитория"])
res = people_cat2.join(people_cat2.pop('Целевая аудитория').str.get_dummies(', '))

# %%
res
# Out:
#        взрослые  дети дошкольного возраста  другое  пенсионеры  \
# 0             0                          0       0           0
# 1             1                          0       0           1
# 2             1                          0       0           1
# 3             0                          1       0           0
# 4             1                          1       0           1
# ...         ...                        ...     ...         ...
# 41069         0                          1       0           0
# 41070         0                          1       0           0
# 41071         1                          1       0           0
# 41072         0                          1       0           0
# 41073         1                          0       0           0
#
#        работающая молодежь  студенческая молодежь  школьники
# 0                        0                      0          0
# 1                        1                      0          0
# 2                        1                      1          1
# 3                        0                      0          1
# 4                        1                      1          1
# ...                    ...                    ...        ...
# 41069                    0                      0          1
# 41070                    0                      0          1
# 41071                    1                      1          1
# 41072                    0                      0          1
# 41073                    1                      1          0
#
# [41074 rows x 7 columns]

# %% [markdown]
# ### Наиболее похожие по описанию мероприятия

# %%
from sklearn.feature_extraction.text import TfidfVectorizer

import string

from nltk.stem.snowball import SnowballStemmer
stemmer = SnowballStemmer("russian")

# %%
russian_stop_words = {
    "words": [
        "а",
        "е",
        "и",
        "ж",
        "м",
        "о",
        "на",
        "не",
        "ни",
        "об",
        "но",
        "он",
        "мне",
        "мои",
        "мож",
        "она",
        "они",
        "оно",
        "мной",
        "много",
        "многочисленное",
        "многочисленная",
        "многочисленные",
        "многочисленный",
        "мною",
        "мой",
        "мог",
        "могут",
        "можно",
        "может",
        "можхо",
        "мор",
        "моя",
        "моё",
        "мочь",
        "над",
        "нее",
        "оба",
        "нам",
        "нем",
        "нами",
        "ними",
        "мимо",
        "немного",
        "одной",
        "одного",
        "менее",
        "однажды",
        "однако",
        "меня",
        "нему",
        "меньше",
        "ней",
        "наверху",
        "него",
        "ниже",
        "мало",
        "надо",
        "один",
        "одиннадцать",
        "одиннадцатый",
        "назад",
        "наиболее",
        "недавно",
        "миллионов",
        "недалеко",
        "между",
        "низко",
        "меля",
        "нельзя",
        "нибудь",
        "непрерывно",
        "наконец",
        "никогда",
        "никуда",
        "нас",
        "наш",
        "нет",
        "нею",
        "неё",
        "них",
        "мира",
        "наша",
        "наше",
        "наши",
        "ничего",
        "начала",
        "нередко",
        "несколько",
        "обычно",
        "опять",
        "около",
        "мы",
        "ну",
        "нх",
        "от",
        "отовсюду",
        "особенно",
        "нужно",
        "очень",
        "отсюда",
        "в",
        "во",
        "вон",
        "вниз",
        "внизу",
        "вокруг",
        "вот",
        "восемнадцать",
        "восемнадцатый",
        "восемь",
        "восьмой",
        "вверх",
        "вам",
        "вами",
        "важное",
        "важная",
        "важные",
        "важный",
        "вдали",
        "везде",
        "ведь",
        "вас",
        "ваш",
        "ваша",
        "ваше",
        "ваши",
        "впрочем",
        "весь",
        "вдруг",
        "вы",
        "все",
        "второй",
        "всем",
        "всеми",
        "времени",
        "время",
        "всему",
        "всего",
        "всегда",
        "всех",
        "всею",
        "всю",
        "вся",
        "всё",
        "всюду",
        "г",
        "год",
        "говорил",
        "говорит",
        "года",
        "году",
        "где",
        "да",
        "ее",
        "за",
        "из",
        "ли",
        "же",
        "им",
        "до",
        "по",
        "ими",
        "под",
        "иногда",
        "довольно",
        "именно",
        "долго",
        "позже",
        "более",
        "должно",
        "пожалуйста",
        "значит",
        "иметь",
        "больше",
        "пока",
        "ему",
        "имя",
        "пор",
        "пора",
        "потом",
        "потому",
        "после",
        "почему",
        "почти",
        "посреди",
        "ей",
        "два",
        "две",
        "двенадцать",
        "двенадцатый",
        "двадцать",
        "двадцатый",
        "двух",
        "его",
        "дел",
        "или",
        "без",
        "день",
        "занят",
        "занята",
        "занято",
        "заняты",
        "действительно",
        "давно",
        "девятнадцать",
        "девятнадцатый",
        "девять",
        "девятый",
        "даже",
        "алло",
        "жизнь",
        "далеко",
        "близко",
        "здесь",
        "дальше",
        "для",
        "лет",
        "зато",
        "даром",
        "первый",
        "перед",
        "затем",
        "зачем",
        "лишь",
        "десять",
        "десятый",
        "ею",
        "её",
        "их",
        "бы",
        "еще",
        "при",
        "был",
        "про",
        "процентов",
        "против",
        "просто",
        "бывает",
        "бывь",
        "если",
        "люди",
        "была",
        "были",
        "было",
        "будем",
        "будет",
        "будете",
        "будешь",
        "прекрасно",
        "буду",
        "будь",
        "будто",
        "будут",
        "ещё",
        "пятнадцать",
        "пятнадцатый",
        "друго",
        "другое",
        "другой",
        "другие",
        "другая",
        "других",
        "есть",
        "пять",
        "быть",
        "лучше",
        "пятый",
        "к",
        "ком",
        "конечно",
        "кому",
        "кого",
        "когда",
        "которой",
        "которого",
        "которая",
        "которые",
        "который",
        "которых",
        "кем",
        "каждое",
        "каждая",
        "каждые",
        "каждый",
        "кажется",
        "как",
        "какой",
        "какая",
        "кто",
        "кроме",
        "куда",
        "кругом",
        "с",
        "т",
        "у",
        "я",
        "та",
        "те",
        "уж",
        "со",
        "то",
        "том",
        "снова",
        "тому",
        "совсем",
        "того",
        "тогда",
        "тоже",
        "собой",
        "тобой",
        "собою",
        "тобою",
        "сначала",
        "только",
        "уметь",
        "тот",
        "тою",
        "хорошо",
        "хотеть",
        "хочешь",
        "хоть",
        "хотя",
        "свое",
        "свои",
        "твой",
        "своей",
        "своего",
        "своих",
        "свою",
        "твоя",
        "твоё",
        "раз",
        "уже",
        "сам",
        "там",
        "тем",
        "чем",
        "сама",
        "сами",
        "теми",
        "само",
        "рано",
        "самом",
        "самому",
        "самой",
        "самого",
        "семнадцать",
        "семнадцатый",
        "самим",
        "самими",
        "самих",
        "саму",
        "семь",
        "чему",
        "раньше",
        "сейчас",
        "чего",
        "сегодня",
        "себе",
        "тебе",
        "сеаой",
        "человек",
        "разве",
        "теперь",
        "себя",
        "тебя",
        "седьмой",
        "спасибо",
        "слишком",
        "так",
        "такое",
        "такой",
        "такие",
        "также",
        "такая",
        "сих",
        "тех",
        "чаще",
        "четвертый",
        "через",
        "часто",
        "шестой",
        "шестнадцать",
        "шестнадцатый",
        "шесть",
        "четыре",
        "четырнадцать",
        "четырнадцатый",
        "сколько",
        "сказал",
        "сказала",
        "сказать",
        "ту",
        "ты",
        "три",
        "эта",
        "эти",
        "что",
        "это",
        "чтоб",
        "этом",
        "этому",
        "этой",
        "этого",
        "чтобы",
        "этот",
        "стал",
        "туда",
        "этим",
        "этими",
        "рядом",
        "тринадцать",
        "тринадцатый",
        "этих",
        "третий",
        "тут",
        "эту",
        "суть",
        "чуть",
        "тысяч",
    ]
}

# %%
def tokenize_text(text):
    words = text.split()
    # remove punctuation from each word
    table = str.maketrans('', '', string.punctuation)
    stripped = [w.translate(table).lower() for w in words]
    removed = [word for word in stripped if word not in set(russian_stop_words["words"])]
    stemmed = [stemmer.stem(word) for word in removed]
    return " ".join(stemmed)

# %%
desc = pd.read_csv(path, usecols=["Краткое описание"])

# %%
tfidf = TfidfVectorizer()
df2 = desc["Краткое описание"].apply(lambda text: tokenize_text(text))
tfidf_matrix = tfidf.fit_transform(df2)
tfidf_matrix.shape
# Out:
# (41074, 36235)

# %%
# Import linear_kernel
from sklearn.metrics.pairwise import linear_kernel

# Compute the cosine similarity matrix
cosine_sim = linear_kernel(tfidf_matrix, tfidf_matrix)

# %%
events = pd.read_csv(
    path,
    usecols=[
        "Название мероприятия",
        "Тип мероприятия",
        "Направленность мероприятия",
        "Краткое описание",
        "Округ",
        "Район",
        "Возрастной ценз участников мероприятия",
        "Возрастная категория",
        "Целевая аудитория",
    ],
)

# %%
events.head()
# Out:
#                                 Название мероприятия  \
# 0  Фестивлаь современных молодежных уличных культ...
# 1  Танцевальный вечер "Ретро" в честь Дня Победы ...
# 2                                           Врасплох
# 3  Праздник Новогодней елки. Новогодний концерт в...
# 4                Выставка к Рождеству "Сувенир Года"
#
#                       Тип мероприятия Направленность мероприятия  \
# 0                           фестиваль        культурно-досуговое
# 1             танцевальный вечер, бал             патриотическое
# 2                            выставка                 антитеррор
# 3  концерт, музыкальное представление        культурно-досуговое
# 4                            выставка        культурно-досуговое
#
#                                     Краткое описание  \
# 0  Клуб Современник проведет фестиваль современны...
# 1      Танцевальный вечер "Ретро" в честь Дня Победы
# 2  Регулярное (ежеквартальное) мероприятие цикла ...
# 3  Коллектив Культурного центра ЗИЛ Ансамбль эстр...
# 4  В преддверии волшебного праздника Рождества Хр...
#
#                           Округ                      Район  \
# 0                           NaN                        NaN
# 1  Южный административный округ                   Нагорный
# 2  Южный административный округ          Нагатинский Затон
# 3                           NaN                        NaN
# 4  Южный административный округ  Орехово-Борисово Северное
#
#   Возрастной ценз участников мероприятия Возрастная категория  \
# 0                                     0+          от 20 до 40
# 1                                    16+          от 40 до 85
# 2                                     6+         от 16 до 100
# 3                                     0+           от 5 до 14
# 4                                     6+          от 15 до 80
#
#                                    Целевая аудитория
# 0                                                NaN
# 1          работающая молодежь, взрослые, пенсионеры
# 2  школьники, работающая молодежь, студенческая м...
# 3               дети дошкольного возраста, школьники
# 4  дети дошкольного возраста, школьники, работающ...

# %%
# Функция выдает 10 наиболее похожих мероприятий на данное, основываясь на кратком описании события
def get_event_recommendations_based_on_description(title, n=10, cosine_sim=cosine_sim):
    indices = pd.Series(events.index, index=events["Название мероприятия"])
    idx = indices[title]
    sim_scores = list(enumerate(cosine_sim[idx]))
    sim_scores = sorted(sim_scores, key=lambda x: x[1], reverse=True)
    sim_scores = sim_scores[1 : n + 1]
    movie_indices = [i[0] for i in sim_scores]
    return events.iloc[movie_indices]

# %%
get_event_recommendations_based_on_description("Врасплох")
# Out:
#                                     Название мероприятия  \
# 13801                                           Заведомо
# 29289                                          Неспроста
# 33433                                        "Неспроста"
# 37070                                        "Неспроста"
# 39275                                          Исподволь
# 9000                  Меры по противодействию терроризму
# 19233  Показ видеороликов по противодействию идеологи...
# 27025                                         "Врасплох"
# 33434                                          "Бережно"
# 5439                                 Гражданская позиция
#
#                                          Тип мероприятия  \
# 13801                                           выставка
# 29289                                           выставка
# 33433                                           выставка
# 37070                                           выставка
# 39275                                           выставка
# 9000                                              лекция
# 19233  просмотр фильмов, мультфильмов, кинолекторий, ...
# 27025                                           выставка
# 33434                                           выставка
# 5439                                               акция
#
#       Направленность мероприятия  \
# 13801                 антитеррор
# 29289                 антитеррор
# 33433                 антитеррор
# 37070                 антитеррор
# 39275                 антитеррор
# 9000                  антитеррор
# 19233                 антитеррор
# 27025                 антитеррор
# 33434           просветительское
# 5439                  антитеррор
#
#                                         Краткое описание  \
# 13801  Регулярное (ежеквартальное) мероприятие цикла ...
# 29289  Регулярное (ежеквартальное) мероприятие цикла ...
# 33433  Регулярное (ежеквартальное) мероприятие цикла ...
# 37070  Регулярное (ежеквартальное) мероприятие цикла ...
# 39275  Регулярное (ежеквартальное) мероприятие цикла ...
# 9000                Меры по противодействию терроризму.
# 19233  В целях противодействия идеологии терроризма и...
# 27025       Выставка информационно-визуальных материалов
# 33434  Выставка информационных материалов для посетит...
# 5439   Тематический показ видеороликов, посвященный п...
#
#                                          Округ              Район  \
# 13801             Южный административный округ  Нагатинский Затон
# 29289             Южный административный округ  Нагатинский Затон
# 33433                                      NaN                NaN
# 37070                                      NaN                NaN
# 39275             Южный административный округ  Нагатинский Затон
# 9000           Северный административный округ            Ховрино
# 19233  Северо-Восточный административный округ        Ярославский
# 27025             Южный административный округ  Нагатинский Затон
# 33434                                      NaN                NaN
# 5439                                       NaN                NaN
#
#       Возрастной ценз участников мероприятия Возрастная категория  \
# 13801                                     6+           от 3 до 10
# 29289                                     6+          от 18 до 99
# 33433                                    12+          от 14 до 35
# 37070                                    12+           от 9 до 14
# 39275                                     6+           от 0 до 99
# 9000                                      0+           от 3 до 99
# 19233                                     6+          от 16 до 35
# 27025                                    12+           от 0 до 99
# 33434                                    12+          от 14 до 35
# 5439                                      6+          от 18 до 99
#
#                                        Целевая аудитория
# 13801                                                NaN
# 29289                                                NaN
# 33433                                                NaN
# 37070                                                NaN
# 39275                                                NaN
# 9000   дети дошкольного возраста, школьники, работающ...
# 19233                                           взрослые
# 27025                                                NaN
# 33434                                                NaN
# 5439   дети дошкольного возраста, школьники, работающ...

# %%
get_event_recommendations_based_on_description('Выставка к Рождеству "Сувенир Года"')
# Out:
#                                     Название мероприятия  \
# 903                                   Праздник Рождества
# 40037  Выставка творческих работ, посвященная встрече...
# 4637                          Концерт "Музыкальный вкус"
# 40035                             Новогодний калейдоскоп
# 647                       Рождество и русская литература
# 40626                           С Рождеством Христовым!
# 709                             Рождественские посиделки
# 7763                                       Юный художник
# 39488                                      Юный художник
# 5068                              Мастер-класс по каратэ
#
#                                          Тип мероприятия  \
# 903    представление, спектакль, инсценировка, перфом...
# 40037                                           выставка
# 4637                  концерт, музыкальное представление
# 40035                                           выставка
# 647      комплексное мероприятие, тематическая программа
# 40626                                           выставка
# 709      комплексное мероприятие, тематическая программа
# 7763                                            выставка
# 39488                                           выставка
# 5068                             игра, игровая программа
#
#                           Направленность мероприятия  \
# 903                              культурно-досуговое
# 40037                            культурно-досуговое
# 4637                             культурно-досуговое
# 40035                            культурно-досуговое
# 647                                 просветительское
# 40626                            культурно-досуговое
# 709                              культурно-досуговое
# 7763                                просветительское
# 39488                               просветительское
# 5068   спортивное, пропаганда здорового образа жизни
#
#                                         Краткое описание  \
# 903    Комплексное мероприятие, посвященное празднику...
# 40037  14 декабря в преддверии Нового года и Рождеств...
# 4637   Концерт "Музыкальный вкус" в 19:00. Борисовски...
# 40035  Новый год – долгожданный праздник, особенно дл...
# 647               Программа посвящена Рождеству Христово
# 40626  Выставка детских творческих работ на кануне пр...
# 709             Мероприятие посвящено Рождеству Христово
# 7763   Выставка работ воспитанников изостудии "Юный х...
# 39488  Выставка работ воспитанников изостудии "Юный х...
# 5068   Мастер-класс по каратэ в 16:00. Борисовский пр...
#
#                                          Округ                      Район  \
# 903    Северо-Восточный административный округ        Северное Медведково
# 40037     Юго-Восточный административный округ            Выхино-Жулебино
# 4637              Южный административный округ  Орехово-Борисово Северное
# 40035   Северо-Западный административный округ                     Щукино
# 647           Восточный административный округ                  Гольяново
# 40626   Северо-Западный административный округ          Хорошёво-Мнёвники
# 709           Восточный административный округ                 Сокольники
# 7763                                       NaN                        NaN
# 39488                                      NaN                        NaN
# 5068              Южный административный округ  Орехово-Борисово Северное
#
#       Возрастной ценз участников мероприятия Возрастная категория  \
# 903                                       0+           от 0 до 90
# 40037                                     0+           от 0 до 99
# 4637                                     12+            от 0 до 6
# 40035                                     0+           от 2 до 90
# 647                                      12+          от 12 до 90
# 40626                                     0+           от 0 до 55
# 709                                       6+           от 6 до 75
# 7763                                      0+           от 3 до 99
# 39488                                     0+           от 3 до 99
# 5068                                     12+           от 6 до 11
#
#                                        Целевая аудитория
# 903    дети дошкольного возраста, школьники, работающ...
# 40037  дети дошкольного возраста, школьники, работающ...
# 4637   школьники, работающая молодежь, студенческая м...
# 40035  дети дошкольного возраста, школьники, студенче...
# 647    школьники, работающая молодежь, студенческая м...
# 40626  дети дошкольного возраста, школьники, работающ...
# 709    дети дошкольного возраста, школьники, работающ...
# 7763   дети дошкольного возраста, школьники, работающ...
# 39488  дети дошкольного возраста, школьники, работающ...
# 5068                                           школьники

# %% [markdown]
# ## Wordcloud

# %%
import matplotlib.pyplot as plt

from wordcloud import WordCloud

# %%
wordcloud = WordCloud().generate(" ".join(df2.values))

# %%
plt.figure(figsize=(15,10))
plt.imshow(wordcloud, interpolation='bilinear')
plt.axis("off")
plt.show()

# %% [markdown]
# ### Предсказание, основанное на кратком описании, типе мероприятия, целевой аудитории, направленности мероприятия

# %%
import numpy as np
from multiprocessing import  Pool

# %%
features = ["Тип мероприятия", "Направленность мероприятия", "Краткое описание", "Целевая аудитория"]
extend_desc = events[features]

# %%
df3 = extend_desc.copy()
df3.fillna("", inplace=True)

# %%
for feature in features:
    df3[feature] = df3[feature].apply(lambda text: tokenize_text(text))

# %%
def tokenize_several_columns(data):
    df = data.copy()
    for col in df.columns:
        df[col] = df[col].apply(lambda text: tokenize_text(text))
    return df

# %%
train = parallelize_dataframe(df3, tokenize_several_columns, n_cores=15)

# %%
def create_soup(df):
    s = ""
    for feature in features:
        s += ' '.join([df[feature]]) + " "
    return s

# %%
df3["soup"] = train.apply(create_soup, axis=1)

# %%
from sklearn.feature_extraction.text import CountVectorizer
from sklearn.metrics.pairwise import cosine_similarity

# %%
# count = CountVectorizer()
# count_matrix = count.fit_transform(df3['soup'])

# cosine_sim2 = cosine_similarity(count_matrix, count_matrix)

# %%
tfidf2 = TfidfVectorizer()
# df2 = desc["Краткое описание"].apply(lambda text: tokenize_text(text))
tfidf_matrix2 = tfidf2.fit_transform(df3['soup'])
tfidf_matrix2.shape
# Out:
# (41074, 34000)

# %%
cosine_sim2 = linear_kernel(tfidf_matrix2, tfidf_matrix2)

# %%
get_event_recommendations_based_on_description("Врасплох", cosine_sim=cosine_sim2)
# Out:
#                                     Название мероприятия  \
# 13801                                           Заведомо
# 29289                                          Неспроста
# 33433                                        "Неспроста"
# 37070                                        "Неспроста"
# 39275                                          Исподволь
# 27025                                         "Врасплох"
# 9000                  Меры по противодействию терроризму
# 19233  Показ видеороликов по противодействию идеологи...
# 5439                                 Гражданская позиция
# 33434                                          "Бережно"
#
#                                          Тип мероприятия  \
# 13801                                           выставка
# 29289                                           выставка
# 33433                                           выставка
# 37070                                           выставка
# 39275                                           выставка
# 27025                                           выставка
# 9000                                              лекция
# 19233  просмотр фильмов, мультфильмов, кинолекторий, ...
# 5439                                               акция
# 33434                                           выставка
#
#       Направленность мероприятия  \
# 13801                 антитеррор
# 29289                 антитеррор
# 33433                 антитеррор
# 37070                 антитеррор
# 39275                 антитеррор
# 27025                 антитеррор
# 9000                  антитеррор
# 19233                 антитеррор
# 5439                  антитеррор
# 33434           просветительское
#
#                                         Краткое описание  \
# 13801  Регулярное (ежеквартальное) мероприятие цикла ...
# 29289  Регулярное (ежеквартальное) мероприятие цикла ...
# 33433  Регулярное (ежеквартальное) мероприятие цикла ...
# 37070  Регулярное (ежеквартальное) мероприятие цикла ...
# 39275  Регулярное (ежеквартальное) мероприятие цикла ...
# 27025       Выставка информационно-визуальных материалов
# 9000                Меры по противодействию терроризму.
# 19233  В целях противодействия идеологии терроризма и...
# 5439   Тематический показ видеороликов, посвященный п...
# 33434  Выставка информационных материалов для посетит...
#
#                                          Округ              Район  \
# 13801             Южный административный округ  Нагатинский Затон
# 29289             Южный административный округ  Нагатинский Затон
# 33433                                      NaN                NaN
# 37070                                      NaN                NaN
# 39275             Южный административный округ  Нагатинский Затон
# 27025             Южный административный округ  Нагатинский Затон
# 9000           Северный административный округ            Ховрино
# 19233  Северо-Восточный административный округ        Ярославский
# 5439                                       NaN                NaN
# 33434                                      NaN                NaN
#
#       Возрастной ценз участников мероприятия Возрастная категория  \
# 13801                                     6+           от 3 до 10
# 29289                                     6+          от 18 до 99
# 33433                                    12+          от 14 до 35
# 37070                                    12+           от 9 до 14
# 39275                                     6+           от 0 до 99
# 27025                                    12+           от 0 до 99
# 9000                                      0+           от 3 до 99
# 19233                                     6+          от 16 до 35
# 5439                                      6+          от 18 до 99
# 33434                                    12+          от 14 до 35
#
#                                        Целевая аудитория
# 13801                                                NaN
# 29289                                                NaN
# 33433                                                NaN
# 37070                                                NaN
# 39275                                                NaN
# 27025                                                NaN
# 9000   дети дошкольного возраста, школьники, работающ...
# 19233                                           взрослые
# 5439   дети дошкольного возраста, школьники, работающ...
# 33434                                                NaN

# %%
get_event_recommendations_based_on_description('Выставка к Рождеству "Сувенир Года"')
# Out:
#                                     Название мероприятия  \
# 903                                   Праздник Рождества
# 40037  Выставка творческих работ, посвященная встрече...
# 4637                          Концерт "Музыкальный вкус"
# 40035                             Новогодний калейдоскоп
# 647                       Рождество и русская литература
# 40626                           С Рождеством Христовым!
# 709                             Рождественские посиделки
# 7763                                       Юный художник
# 39488                                      Юный художник
# 5068                              Мастер-класс по каратэ
#
#                                          Тип мероприятия  \
# 903    представление, спектакль, инсценировка, перфом...
# 40037                                           выставка
# 4637                  концерт, музыкальное представление
# 40035                                           выставка
# 647      комплексное мероприятие, тематическая программа
# 40626                                           выставка
# 709      комплексное мероприятие, тематическая программа
# 7763                                            выставка
# 39488                                           выставка
# 5068                             игра, игровая программа
#
#                           Направленность мероприятия  \
# 903                              культурно-досуговое
# 40037                            культурно-досуговое
# 4637                             культурно-досуговое
# 40035                            культурно-досуговое
# 647                                 просветительское
# 40626                            культурно-досуговое
# 709                              культурно-досуговое
# 7763                                просветительское
# 39488                               просветительское
# 5068   спортивное, пропаганда здорового образа жизни
#
#                                         Краткое описание  \
# 903    Комплексное мероприятие, посвященное празднику...
# 40037  14 декабря в преддверии Нового года и Рождеств...
# 4637   Концерт "Музыкальный вкус" в 19:00. Борисовски...
# 40035  Новый год – долгожданный праздник, особенно дл...
# 647               Программа посвящена Рождеству Христово
# 40626  Выставка детских творческих работ на кануне пр...
# 709             Мероприятие посвящено Рождеству Христово
# 7763   Выставка работ воспитанников изостудии "Юный х...
# 39488  Выставка работ воспитанников изостудии "Юный х...
# 5068   Мастер-класс по каратэ в 16:00. Борисовский пр...
#
#                                          Округ                      Район  \
# 903    Северо-Восточный административный округ        Северное Медведково
# 40037     Юго-Восточный административный округ            Выхино-Жулебино
# 4637              Южный административный округ  Орехово-Борисово Северное
# 40035   Северо-Западный административный округ                     Щукино
# 647           Восточный административный округ                  Гольяново
# 40626   Северо-Западный административный округ          Хорошёво-Мнёвники
# 709           Восточный административный округ                 Сокольники
# 7763                                       NaN                        NaN
# 39488                                      NaN                        NaN
# 5068              Южный административный округ  Орехово-Борисово Северное
#
#       Возрастной ценз участников мероприятия Возрастная категория  \
# 903                                       0+           от 0 до 90
# 40037                                     0+           от 0 до 99
# 4637                                     12+            от 0 до 6
# 40035                                     0+           от 2 до 90
# 647                                      12+          от 12 до 90
# 40626                                     0+           от 0 до 55
# 709                                       6+           от 6 до 75
# 7763                                      0+           от 3 до 99
# 39488                                     0+           от 3 до 99
# 5068                                     12+           от 6 до 11
#
#                                        Целевая аудитория
# 903    дети дошкольного возраста, школьники, работающ...
# 40037  дети дошкольного возраста, школьники, работающ...
# 4637   школьники, работающая молодежь, студенческая м...
# 40035  дети дошкольного возраста, школьники, студенче...
# 647    школьники, работающая молодежь, студенческая м...
# 40626  дети дошкольного возраста, школьники, работающ...
# 709    дети дошкольного возраста, школьники, работающ...
# 7763   дети дошкольного возраста, школьники, работающ...
# 39488  дети дошкольного возраста, школьники, работающ...
# 5068                                           школьники

# %% [markdown]
# ## Clustering based on the TFIDF

# %%
from sklearn.cluster import KMeans

# %%
km = KMeans(n_clusters=5, max_iter=200, n_init=10)
km = km.fit(tfidf_matrix2)

# %%
events_with_clusters = events.copy()
events_with_clusters["cluster"] = km.labels_

# %%
collections.Counter(km.labels_)
# Out:
# Counter({0: 23115, 1: 6902, 4: 5117, 3: 4341, 2: 1599})

# %%
events_with_clusters["clean_description"] = df2

# %%
for group, df in events_with_clusters[["clean_description", "cluster"]].groupby("cluster"):
    print(f"Cluster {group}")
#     print(df["clean_description"].values)
    wordcloud = WordCloud().generate(" ".join((df["clean_description"].values)))
    plt.figure(figsize=(15,10))
    plt.imshow(wordcloud, interpolation='bilinear')
    plt.axis("off")
    plt.show()
#     break
# Out:
# Cluster 0
# Cluster 1
# Cluster 2
# Cluster 3
# Cluster 4
